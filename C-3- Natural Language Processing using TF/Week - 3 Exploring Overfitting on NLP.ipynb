# %%
import json
import tensorflow as tf
import csv
import random
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers


embedding_dim = 100
max_length = 16
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size=160000
test_portion=.1

corpus = []

# %%
# Note that I cleaned the Stanford dataset to remove LATIN1 encoding to make it easier for Python CSV reader
# You can do that yourself with:
# iconv -f LATIN1 -t UTF8 training.1600000.processed.noemoticon.csv -o training_cleaned.csv
# I then hosted it on my site to make it easier to use in this notebook

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv \
    -O /tmp/training_cleaned.csv

num_sentences = 0

with open("/tmp/training_cleaned.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        list_item=[]
        list_item.append(row[5])
        this_label=row[0]
        if this_label=='0':
            list_item.append(0)
        else:
            list_item.append(1)
        num_sentences = num_sentences + 1
        corpus.append(list_item)
# Out:
# --2020-10-14 06:28:47--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.97.128, 74.125.203.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.97.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238942690 (228M) [application/octet-stream]
# Saving to: ‘/tmp/training_cleaned.csv’
#
# /tmp/training_clean 100%[===================>] 227.87M  64.8MB/s    in 3.5s
#
# 2020-10-14 06:28:51 (64.8 MB/s) - ‘/tmp/training_cleaned.csv’ saved [238942690/238942690]

# %%
print(num_sentences)
print(len(corpus))
print(corpus[1])

# Expected Output:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]
# Out:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]

# %%
sentences=[]
labels=[]
random.shuffle(corpus)
for x in range(training_size):
    sentences.append(corpus[x][0])
    labels.append(corpus[x][1])


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size=len(word_index)

sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

split = int(test_portion * training_size)

test_sequences = padded[0:split]
training_sequences = padded[split:training_size]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
print(vocab_size)
print(word_index['i'])
# Expected Output
# 138858
# 1
# Out:
# 138263
# 1

# %%
# Note this is the 100 dimension version of GloVe from Stanford
# I unzipped and hosted it on my site to make this notebook easier
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/tmp/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;

embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2020-10-14 06:30:34--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.189.128, 108.177.97.128, 108.177.125.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.189.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 347116733 (331M) [text/plain]
# Saving to: ‘/tmp/glove.6B.100d.txt’
#
# /tmp/glove.6B.100d. 100%[===================>] 331.04M  37.5MB/s    in 8.8s
#
# 2020-10-14 06:30:44 (37.5 MB/s) - ‘/tmp/glove.6B.100d.txt’ saved [347116733/347116733]

# %%
print(len(embeddings_matrix))
# Expected Output
# 138859
# Out:
# 138859

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=max_length, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50

training_padded = np.array(training_sequences)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 16, 100)           13826400
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 100)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 12, 64)            32064
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3, 64)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 13,891,553
# Trainable params: 65,153
# Non-trainable params: 13,826,400
# _________________________________________________________________
# Epoch 1/50
# 4500/4500 - 19s - loss: 0.5661 - accuracy: 0.7006 - val_loss: 0.5219 - val_accuracy: 0.7321
# Epoch 2/50
# 4500/4500 - 19s - loss: 0.5248 - accuracy: 0.7342 - val_loss: 0.5096 - val_accuracy: 0.7454
# Epoch 3/50
# 4500/4500 - 19s - loss: 0.5107 - accuracy: 0.7441 - val_loss: 0.5035 - val_accuracy: 0.7475
# Epoch 4/50
# 4500/4500 - 19s - loss: 0.4990 - accuracy: 0.7516 - val_loss: 0.5011 - val_accuracy: 0.7501
# Epoch 5/50
# 4500/4500 - 21s - loss: 0.4900 - accuracy: 0.7571 - val_loss: 0.4992 - val_accuracy: 0.7505
# Epoch 6/50
# 4500/4500 - 20s - loss: 0.4844 - accuracy: 0.7624 - val_loss: 0.4971 - val_accuracy: 0.7531
# Epoch 7/50
# 4500/4500 - 19s - loss: 0.4770 - accuracy: 0.7668 - val_loss: 0.5170 - val_accuracy: 0.7389
# Epoch 8/50
# 4500/4500 - 19s - loss: 0.4725 - accuracy: 0.7687 - val_loss: 0.5013 - val_accuracy: 0.7494
# Epoch 9/50
# 4500/4500 - 19s - loss: 0.4686 - accuracy: 0.7711 - val_loss: 0.5117 - val_accuracy: 0.7449
# Epoch 10/50
# 4500/4500 - 19s - loss: 0.4651 - accuracy: 0.7747 - val_loss: 0.5102 - val_accuracy: 0.7461
# Epoch 11/50
# 4500/4500 - 19s - loss: 0.4612 - accuracy: 0.7765 - val_loss: 0.5062 - val_accuracy: 0.7523
# Epoch 12/50
# 4500/4500 - 19s - loss: 0.4577 - accuracy: 0.7789 - val_loss: 0.5023 - val_accuracy: 0.7521
# Epoch 13/50
# 4500/4500 - 19s - loss: 0.4545 - accuracy: 0.7808 - val_loss: 0.5039 - val_accuracy: 0.7546
# Epoch 14/50
# 4500/4500 - 19s - loss: 0.4527 - accuracy: 0.7817 - val_loss: 0.5067 - val_accuracy: 0.7520
# Epoch 15/50
# 4500/4500 - 19s - loss: 0.4519 - accuracy: 0.7820 - val_loss: 0.5136 - val_accuracy: 0.7527
# Epoch 16/50
# 4500/4500 - 19s - loss: 0.4476 - accuracy: 0.7859 - val_loss: 0.5113 - val_accuracy: 0.7508
# Epoch 17/50
# 4500/4500 - 19s - loss: 0.4470 - accuracy: 0.7850 - val_loss: 0.5062 - val_accuracy: 0.7544
# Epoch 18/50
# 4500/4500 - 19s - loss: 0.4446 - accuracy: 0.7871 - val_loss: 0.5121 - val_accuracy: 0.7535
# Epoch 19/50
# 4500/4500 - 19s - loss: 0.4444 - accuracy: 0.7860 - val_loss: 0.5128 - val_accuracy: 0.7484
# Epoch 20/50
# 4500/4500 - 19s - loss: 0.4429 - accuracy: 0.7881 - val_loss: 0.5101 - val_accuracy: 0.7505
# Epoch 21/50
# 4500/4500 - 20s - loss: 0.4427 - accuracy: 0.7874 - val_loss: 0.5106 - val_accuracy: 0.7533
# Epoch 22/50
# 4500/4500 - 20s - loss: 0.4412 - accuracy: 0.7893 - val_loss: 0.5098 - val_accuracy: 0.7512
# Epoch 23/50
# 4500/4500 - 19s - loss: 0.4393 - accuracy: 0.7893 - val_loss: 0.5165 - val_accuracy: 0.7484
# Epoch 24/50
# 4500/4500 - 19s - loss: 0.4385 - accuracy: 0.7896 - val_loss: 0.5115 - val_accuracy: 0.7495
# Epoch 25/50
# 4500/4500 - 19s - loss: 0.4378 - accuracy: 0.7896 - val_loss: 0.5176 - val_accuracy: 0.7519
# Epoch 26/50
# 4500/4500 - 19s - loss: 0.4376 - accuracy: 0.7900 - val_loss: 0.5165 - val_accuracy: 0.7483
# Epoch 27/50
# 4500/4500 - 19s - loss: 0.4363 - accuracy: 0.7929 - val_loss: 0.5186 - val_accuracy: 0.7500
# Epoch 28/50
# 4500/4500 - 19s - loss: 0.4363 - accuracy: 0.7915 - val_loss: 0.5171 - val_accuracy: 0.7477
# Epoch 29/50
# 4500/4500 - 19s - loss: 0.4340 - accuracy: 0.7929 - val_loss: 0.5194 - val_accuracy: 0.7454
# Epoch 30/50
# 4500/4500 - 19s - loss: 0.4337 - accuracy: 0.7933 - val_loss: 0.5144 - val_accuracy: 0.7512
# Epoch 31/50
# 4500/4500 - 19s - loss: 0.4341 - accuracy: 0.7920 - val_loss: 0.5205 - val_accuracy: 0.7481
# Epoch 32/50
# 4500/4500 - 19s - loss: 0.4319 - accuracy: 0.7937 - val_loss: 0.5205 - val_accuracy: 0.7479
# Epoch 33/50
# 4500/4500 - 19s - loss: 0.4340 - accuracy: 0.7936 - val_loss: 0.5148 - val_accuracy: 0.7498
# Epoch 34/50
# 4500/4500 - 19s - loss: 0.4315 - accuracy: 0.7945 - val_loss: 0.5242 - val_accuracy: 0.7474
# Epoch 35/50
# 4500/4500 - 19s - loss: 0.4338 - accuracy: 0.7930 - val_loss: 0.5235 - val_accuracy: 0.7483
# Epoch 36/50
# 4500/4500 - 19s - loss: 0.4310 - accuracy: 0.7952 - val_loss: 0.5215 - val_accuracy: 0.7481
# Epoch 37/50
# 4500/4500 - 20s - loss: 0.4325 - accuracy: 0.7945 - val_loss: 0.5178 - val_accuracy: 0.7461
# Epoch 38/50
# 4500/4500 - 20s - loss: 0.4289 - accuracy: 0.7956 - val_loss: 0.5250 - val_accuracy: 0.7481
# Epoch 39/50
# 4500/4500 - 19s - loss: 0.4290 - accuracy: 0.7972 - val_loss: 0.5282 - val_accuracy: 0.7471
# Epoch 40/50
# 4500/4500 - 19s - loss: 0.4306 - accuracy: 0.7952 - val_loss: 0.5165 - val_accuracy: 0.7519
# Epoch 41/50
# 4500/4500 - 19s - loss: 0.4301 - accuracy: 0.7947 - val_loss: 0.5237 - val_accuracy: 0.7492
# Epoch 42/50
# 4500/4500 - 19s - loss: 0.4288 - accuracy: 0.7967 - val_loss: 0.5205 - val_accuracy: 0.7477
# Epoch 43/50
# 4500/4500 - 19s - loss: 0.4277 - accuracy: 0.7961 - val_loss: 0.5208 - val_accuracy: 0.7475
# Epoch 44/50
# 4500/4500 - 19s - loss: 0.4289 - accuracy: 0.7956 - val_loss: 0.5199 - val_accuracy: 0.7483
# Epoch 45/50
# 4500/4500 - 19s - loss: 0.4274 - accuracy: 0.7977 - val_loss: 0.5228 - val_accuracy: 0.7476
# Epoch 46/50
# 4500/4500 - 19s - loss: 0.4291 - accuracy: 0.7962 - val_loss: 0.5220 - val_accuracy: 0.7500
# Epoch 47/50
# 4500/4500 - 19s - loss: 0.4282 - accuracy: 0.7969 - val_loss: 0.5226 - val_accuracy: 0.7491
# Epoch 48/50
# 4500/4500 - 19s - loss: 0.4278 - accuracy: 0.7971 - val_loss: 0.5225 - val_accuracy: 0.7504
# Epoch 49/50
# 4500/4500 - 19s - loss: 0.4262 - accuracy: 0.7969 - val_loss: 0.5209 - val_accuracy: 0.7508
# Epoch 50/50
# 4500/4500 - 19s - loss: 0.4267 - accuracy: 0.7974 - val_loss: 0.5208 - val_accuracy: 0.7486
# Training Complete

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])

plt.figure()


# Expected Output
# A chart where the validation loss does not increase sharply!
